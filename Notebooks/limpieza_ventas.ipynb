# %%
import pandas as pd

# %%
# Cargamos las ventas
df_ventas = pd.read_excel(r"C:\Users\Yo\OneDrive\Desktop\IA\ProyectoAurelion_EricaAlmiron\datos_originalesAurelion\ventas.xlsx")

# %%
# Mostrar las primeras 10 filas del DataFrame
df_ventas.head(10)
# Out:
#    id_venta      fecha  id_cliente     nombre_cliente  \
# 0         1 2024-06-19          62   Guadalupe Romero
# 1         2 2024-03-17          49       Olivia Gomez
# 2         3 2024-01-13          20       Tomas Acosta
# 3         4 2024-02-27          36     Martina Molina
# 4         5 2024-06-11          56         Bruno Diaz
# 5         6 2024-05-05          91        Uma Sanchez
# 6         7 2024-05-06          92  Mariana Rodriguez
# 7         8 2024-01-06          66      Tomas Herrera
# 8         9 2024-01-20          86       Diego Torres
# 9        10 2024-05-28          52         Diego Diaz
#
#                         email     medio_pago
# 0   guadalupe.romero@mail.com        tarjeta
# 1       olivia.gomez@mail.com             qr
# 2       tomas.acosta@mail.com        tarjeta
# 3     martina.molina@mail.com  transferencia
# 4         bruno.diaz@mail.com        tarjeta
# 5        uma.sanchez@mail.com  transferencia
# 6  mariana.rodriguez@mail.com       efectivo
# 7      tomas.herrera@mail.com  transferencia
# 8       diego.torres@mail.com       efectivo
# 9         diego.diaz@mail.com             qr

# %%
# 🔍 Información general del DataFrame 
#    Paso 1: Inspección inicial de los datos
df_ventas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id_venta        120 non-null    int64
#  1   fecha           120 non-null    datetime64[ns]
#  2   id_cliente      120 non-null    int64
#  3   nombre_cliente  120 non-null    object
#  4   email           120 non-null    object
#  5   medio_pago      120 non-null    object
# dtypes: datetime64[ns](1), int64(2), object(3)
# memory usage: 5.8+ KB

# %%
# 📊 Estadísticas descriptivas de las columnas
df_ventas.describe(include='all')
# Out:
#           id_venta                fecha  id_cliente nombre_cliente  \
# count   120.000000                  120  120.000000            120
# unique         NaN                  NaN         NaN             64
# top            NaN                  NaN         NaN     Bruno Diaz
# freq           NaN                  NaN         NaN              5
# mean     60.500000  2024-03-29 17:36:00   47.291667            NaN
# min       1.000000  2024-01-02 00:00:00    1.000000            NaN
# 25%      30.750000  2024-02-11 06:00:00   24.500000            NaN
# 50%      60.500000  2024-03-25 00:00:00   48.500000            NaN
# 75%      90.250000  2024-05-19 06:00:00   67.500000            NaN
# max     120.000000  2024-06-28 00:00:00  100.000000            NaN
# std      34.785054                  NaN   27.854181            NaN
#
#                       email medio_pago
# count                   120        120
# unique                   67          4
# top     bruno.diaz@mail.com   efectivo
# freq                      5         37
# mean                    NaN        NaN
# min                     NaN        NaN
# 25%                     NaN        NaN
# 50%                     NaN        NaN
# 75%                     NaN        NaN
# max                     NaN        NaN
# std                     NaN        NaN

# %%
#duplicados en todo el DataFrame
df_ventas.duplicated().sum()
# Out:
# np.int64(0)

# %%
#duplicados en `id_venta`
df_ventas['id_venta'].duplicated().sum()
# Out:
# np.int64(0)

# %%
#Buscar valores nulos
df_ventas.isnull().sum()
# Out:
# id_venta          0
# fecha             0
# id_cliente        0
# nombre_cliente    0
# email             0
# medio_pago        0
# dtype: int64

# %%
# ver filas duplicadas exactas
duplicados_exactos = df_ventas[df_ventas.duplicated(keep=False)]
duplicados_exactos.shape
# Out:
# (0, 6)

# %%
#Revisar tipos de datos (dtypes)
df_ventas.dtypes
# Out:
# id_venta                   int64
# fecha             datetime64[ns]
# id_cliente                 int64
# nombre_cliente            object
# email                     object
# medio_pago                object
# dtype: object

# %%
#total filas
df_ventas.shape[0]
# Out:
# 120

# %%
#total columnas
df_ventas.shape[1]
# Out:
# 6

# %%
# 6️⃣ Guardar el archivo limpio
df_ventas.to_csv('ventas_limpios.csv', index=False, encoding='utf-8')
print("✅ Archivo limpio exportado correctamente: ventas_limpios.csv")
# Out:
# ✅ Archivo limpio exportado correctamente: ventas_limpios.csv
